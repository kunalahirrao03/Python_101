# %%
list1 = [ 'a','b']
         
list1.append([1,2,3])

print(list1)
# Out:
# ['a', 'b', [1, 2, 3]]

# %%
list1 = [ 'a','b']
list1.append([1,2,3])
for i in list1:
 print(type(i))
print(list1)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'list'>
# ['a', 'b', [1, 2, 3]]

# %%
list1 = [ 'a','b']
list1.append([1,2,3])
list1.extend(["abc",'dce'])
 
print(list1)
# Out:
# ['a', 'b', [1, 2, 3], 'abc', 'dce']

# %%
list1 = [ 'a','b']
list1.append([1,2,3])
list1.extend(["abc",'dce'])
list1.insert(1,"xyz")
print(list1)
# Out:
# ['a', 'xyz', 'b', [1, 2, 3], 'abc', 'dce']

# %%
list1 = [ 'a','b']
list1.append([1,2,3])
list1.extend(["abc",'dce'])
list1.insert(1,"xyz")
list1.insert(10,"xyz")
print(list1)
# Out:
# ['a', 'xyz', 'b', [1, 2, 3], 'abc', 'dce', 'xyz']

# %%
list1 = [ 'a','b']
list1.append([1,2,3])
list1.extend(["abc",'dce'])
list1.insert(1,"xyz")
list1.insert(10,"xyz")
list1.pop()
print(list1)
# Out:
# ['a', 'xyz', 'b', [1, 2, 3], 'abc', 'dce']

# %%
list1 = [ 'a','b']
list1.append([1,2,3])
list1.extend(["abc",'dce'])
list1.insert(1,"xyz")
list1.insert(10,"xyz")
list1.pop()
list1.pop(1)
print(list1)
# Out:
# ['a', 'b', [1, 2, 3], 'abc', 'dce']

# %%
list1 = [ 'a','b']
list1.append([1,2,3])
list1.extend(["abc",'dce'])
list1.insert(1,"xyz")
list1.insert(10,"xyz")
list1.pop()
list1.pop(1)
list1.remove('abc')
print(list1)
# Out:
# ['a', 'b', [1, 2, 3], 'dce']

# %%
list1 = [ 'a','b']
list1.append([1,2,3])
list1.extend(["abc",'dce'])
list1.insert(1,"xyz")
list1.insert(10,"xyz")
list1.pop()
list1.pop(1)
list1.remove('abc')
list1.pop(2)
list1.pop(2)
print(list1)
# Out:
# ['a', 'b']

# %%
list1 = [1,1,2,2,3,3]
s = set(list1)
T = tuple(list1)
print(s)
print(T)
# Out:
# {1, 2, 3}
# (1, 1, 2, 2, 3, 3)

# %%
s = set('aabbccddee')
print(s)
# Out:
# {'c', 'e', 'a', 'd', 'b'}

# %%
s = {0,1,'1','p',True ,"true"}
print(s)
# Out:
# {0, 1, 'true', 'p', '1'}

# %% [markdown]
# #1/0 is also a true or false so it take it same and remove dublicate

# %%
l1 = ['a','b']
print(l1[1])
# Out:
# b

# %%
D1 = {"name":"kunal",
      "roll no": "b12",
      "address":"xyz"}
print(type(D1))
# Out:
# <class 'dict'>

# %%
D1 = {"name":"kunal",
      "roll no": "b12",
      "address":"xyz"}
for x in D1.keys():
    print(x)
# Out:
# name
# roll no
# address

# %%
D1 = {"name":"kunal",
      "roll no": "b12",
      "address":"xyz"}
for x in D1.keys():
    print(x)
for y in D1.values():
    print(y)
# Out:
# name
# roll no
# address
# kunal
# b12
# xyz

# %%
list1 = ["a",'b','c']
list2 = ['e','r']
D2 = dict(zip(list1,list2))
print(D2)
# Out:
# {'a': 'e', 'b': 'r'}
