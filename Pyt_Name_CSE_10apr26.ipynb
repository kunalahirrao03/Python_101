# %%
list1 = [ 'a','b']
         
list1.append([1,2,3])

print(list1)
# Out:
# ['a', 'b', [1, 2, 3]]

# %%
list1 = [ 'a','b']
list1.append([1,2,3])
for i in list1:
 print(type(i))
print(list1)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'list'>
# ['a', 'b', [1, 2, 3]]

# %%
list1 = [ 'a','b']
list1.append([1,2,3])
list1.extend(["abc",'dce'])
 
print(list1)
# Out:
# ['a', 'b', [1, 2, 3], 'abc', 'dce']

# %%
list1 = [ 'a','b']
list1.append([1,2,3])
list1.extend(["abc",'dce'])
list1.insert(1,"xyz")
print(list1)
# Out:
# ['a', 'xyz', 'b', [1, 2, 3], 'abc', 'dce']

# %%
list1 = [ 'a','b']
list1.append([1,2,3])
list1.extend(["abc",'dce'])
list1.insert(1,"xyz")
list1.insert(10,"xyz")
print(list1)
# Out:
# ['a', 'xyz', 'b', [1, 2, 3], 'abc', 'dce', 'xyz']

# %%
list1 = [ 'a','b']
list1.append([1,2,3])
list1.extend(["abc",'dce'])
list1.insert(1,"xyz")
list1.insert(10,"xyz")
list1.pop()
print(list1)
# Out:
# ['a', 'xyz', 'b', [1, 2, 3], 'abc', 'dce']

# %%
list1 = [ 'a','b']
list1.append([1,2,3])
list1.extend(["abc",'dce'])
list1.insert(1,"xyz")
list1.insert(10,"xyz")
list1.pop()
list1.pop(1)
print(list1)
# Out:
# ['a', 'b', [1, 2, 3], 'abc', 'dce']

# %%
list1 = [ 'a','b']
list1.append([1,2,3])
list1.extend(["abc",'dce'])
list1.insert(1,"xyz")
list1.insert(10,"xyz")
list1.pop()
list1.pop(1)
list1.remove('abc')
print(list1)
# Out:
# ['a', 'b', [1, 2, 3], 'dce']

# %%
list1 = [ 'a','b']
list1.append([1,2,3])
list1.extend(["abc",'dce'])
list1.insert(1,"xyz")
list1.insert(10,"xyz")
list1.pop()
list1.pop(1)
list1.remove('abc')
list1.pop(2)
list1.pop(2)
print(list1)
# Out:
# ['a', 'b']
