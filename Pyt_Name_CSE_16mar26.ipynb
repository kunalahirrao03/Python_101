# %% [markdown]
# Ansewr

# %%
print("Hello Wolrd!" , "Have a good day." , "learning python is fun!")
# Out:
# Hello Wolrd! Have a good day. learning python is fun!

# %%
print("Hello");print("How are you?");print("Bye Bye!")
# Out:
# Hello
# How are you?
# Bye Bye!

# %%
a = int(25)
b = "I am" + a + "Years old."
print(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 a = int(25)
# ----> 2 b = "I am" + a + "Years old."
#       3 print(b)
#
# TypeError: can only concatenate str (not "int") to str

# %%
name = "kunal"
age = int(20)
print(name , age)
# Out:
# kunal 20

# %%
x,y,z = "Apple" , "Mango" , "Banana"
print(x,y,z)
# Out:
# Apple Mango Banana

# %%
a = str(5)
b = int(7.8)
c = float(9)
print(a , b , c)
# Out:
# 5 7 9.0

# %%
num = 10
text = str(num)

print(text)
print(type(text))
# Out:
# 10
# <class 'str'>

# %%
num = 20
text = float(num)

print(text)
print(type(text))
# Out:
# 20.0
# <class 'float'>
